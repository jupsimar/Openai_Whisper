# %%
# !pip install git+https://github.com/openai/whisper.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-3qcir4ee
#   Running command git clone -q https://github.com/openai/whisper.git /tmp/pip-req-build-3qcir4ee
# ...
#      |████████████████████████████████| 5.5 MB 4.5 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 49.5 MB/s
# ...
#      |████████████████████████████████| 163 kB 53.3 MB/s
# ...
#   Created wheel for whisper: filename=whisper-1.0-py3-none-any.whl size=1175217 sha256=2e1089c613ad68570a16f8a7574a97f3e94a80c4b03198d571148aae6c8c616a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-raej00ye/wheels/16/15/89/1c7bb31bd0006793a95549d04785121a8a36daad9158e1e43a
# Successfully built whisper
# ...

# %%
# Import Whisper
 import whisper

# %%
# Loading the model 

#model = whisper.load_model("base")
model = whisper.load_model("medium")

# %%
# Audio Input to the model
# Sample input from Web : Refer :https://audio-samples.github.io/

out = model.transcribe("/content/drive/MyDrive/sample-2.mp3",language = "hi")
# Out:
# /usr/local/lib/python3.7/dist-packages/whisper/transcribe.py:78: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")

# %%
out
# Out:
# {'text': ' तो मैं पाँवादा पाइटा पाइटा पाइटा पाइटा। वे जेन्नाल नहीं पाइटा पाइटा पाइटा पाइटा पाइटा। वे जेनाल नहीं पाइटा पाइटा पाइटा।',
#  'segments': [{'id': 0,
#    'seek': 0,
#    'start': 0.0,
#    'end': 3.42,
#    'text': ' तो मैं पाँवादा पाइटा पाइटा पाइटा पाइटा।',
#    'tokens': [50364,
#     8485,
#     97,
#     33926,
#     48449,
#     43372,
#     31945,
#     8485,
#     103,
#     17937,
#     3941,
#     223,
#     3941,
#     113,
#     17937,
#     3941,
#     99,
#     17937,
#     8485,
#     103,
#     17937,
#     3941,
#     229,
#     3941,
#     253,
#     17937,
#     8485,
#     103,
#     17937,
#     3941,
#     229,
#     3941,
#     253,
#     17937,
#     8485,
#     103,
#     17937,
#     3941,
#     229,
#     3941,
#     253,
#     17937,
#     8485,
#     103,
#     17937,
#     3941,
#     229,
#     3941,
#     253,
#     17937,
#     8703,
#     97,
#     50535,
#     50535,
#     8485,
#     113,
#     21981,
#     8485,
#     250,
#     21981,
# ...
